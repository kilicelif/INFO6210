# %% [markdown]
# ### Database Project Two (NoSQL)

# %% [markdown]
# Required libraries are imported:

# %%
import sqlite3
import pandas as pd
import csv
# %matplotlib inline
import pymongo
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure
from bson import json_util, ObjectId
import pandas as pd
from pandas import DataFrame
from pandas.io.json import json_normalize
import numpy as np
import requests
import json, os
import configparser
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import warnings
import random
import pprint
from datetime import datetime
random.seed(datetime.now())
warnings.filterwarnings('ignore')

# Make plots larger
plt.rcParams['figure.figsize'] = (10, 6)

# %%
#python connected to sqlite db file 
sqlite_file = 'project.db'
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# %%
conn.close()

# %%
#it is connected to mongodb
import pymongo
conn = pymongo.MongoClient()
conn
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
#local host is specified
MongoClient('localhost', 27017)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
#conn.database_names()

db = conn['elif-proj-final-twit']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'elif-proj-final-twit')

# %%
#collection is defined
collection = db.twitter
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'elif-proj-final-twit'), 'twitter')

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'elif-proj-final-twit'), 'twitter')

# %%
#csv file is imported and converted to json format

def load_csv(csv):
    p=os.path.join("data/", csv)
    print (p)
    data=pd.read_csv(p, encoding = "ISO-8859-1", engine='python')
    return data 
tweets_csv=load_csv('C:/Users/kilic/Desktop/finaldata.csv')
tweets_csv.head()
# Out:
# C:/Users/kilic/Desktop/finaldata.csv
#                    id       created_at  favourite_count  retweet_count  \
# 0  984219499846128000  4/11/2018 23:59                0             24
# 1  984219494112428000  4/11/2018 23:59                0             73
# 2  984219485954630000  4/11/2018 23:59                0             38
# 3  984219472675434000  4/11/2018 23:59                0             41
# 4  984219470678974000  4/11/2018 23:59                5              6
#
#   user_screen_name  user_followers_count                   user_location  \
# 0  creativemindgrp                  1782  US | CANADA | FRANCE | GERMANY
# 1         paotrrzs                   598                          Mxico
# 2    Sense8giflord                   484                    Florida, USA
# 3  angelicadianna_                   267                             NaN
# 4         paotrrzs                   598                          Mxico
#
#                                             hashtags urls media  \
# 0          [{'text': 'Cannes', 'indices': [21, 28]}]    N     N
# 1                                                 []    N     N
# 2                                                 []    N     N
# 3                                                 []    N     N
# 4  [{'text': 'RenewEverythingSucks', 'indices': [...    Y     N
#
#                                                 text
# 0  RT @Variety: After a #Cannes rule change that ...
# 1  RT @westmetromommy: Seriously, if you haven?t ...
# 2  RT @Global_Cluster: I have somethings to say, ...
# 3  RT @baleadalover: I don?t even watch this show...
# 4  @netflix see how much we love it. Please #Rene...

# %%
#csv dataset is converted to jso format and assigned to new.
new =json.loads(tweets_csv.to_json(orient='records'))
new[0]
# Out:
# {'created_at': '4/11/2018 23:59',
#  'favourite_count': 0,
#  'hashtags': "[{'text': 'Cannes', 'indices': [21, 28]}]",
#  'id': 984219499846128000,
#  'media': 'N',
#  'retweet_count': 24,
#  'text': 'RT @Variety: After a #Cannes rule change that bans films without a France theatrical release from playing in competition, @Netflix is sitti?',
#  'urls': 'N',
#  'user_followers_count': 1782,
#  'user_location': 'US | CANADA | FRANCE | GERMANY',
#  'user_screen_name': 'creativemindgrp'}

# %%
try:
    result = db.twitter.drop()
    print ("analytics tweets dropped")
except:
    pass
# Out:
# analytics tweets dropped

# %%
#  ObjectId('5ae3982378c51348e0df3634'),
#  ObjectId('5ae3982378c51348e0df3635'),
#  ObjectId('5ae3982378c51348e0df3636'),
#  ObjectId('5ae3982378c51348e0df3637'),
#  ObjectId('5ae3982378c51348e0df3638'),
#  ObjectId('5ae3982378c51348e0df3639'),
#  ObjectId('5ae3982378c51348e0df363a'),
#  ObjectId('5ae3982378c51348e0df363b'),
#  ObjectId('5ae3982378c51348e0df363c'),
#  ObjectId('5ae3982378c51348e0df363d'),
#  ObjectId('5ae3982378c51348e0df363e'),
#  ObjectId('5ae3982378c51348e0df363f'),
#  ObjectId('5ae3982378c51348e0df3640'),
#  ObjectId('5ae3982378c51348e0df3641'),
#  ObjectId('5ae3982378c51348e0df3642'),
#  ObjectId('5ae3982378c51348e0df3643'),
#  ObjectId('5ae3982378c51348e0df3644'),
#  ObjectId('5ae3982378c51348e0df3645'),
#  ...]

# %%
#First five documents are printed to check the content of the collection
for d in collection.find()[:].limit(5):
    print(d)
# Out:
# {'_id': ObjectId('5ae3982378c51348e0df325e'), 'id': 984219499846128000, 'created_at': '4/11/2018 23:59', 'favourite_count': 0, 'retweet_count': 24, 'user_screen_name': 'creativemindgrp', 'user_followers_count': 1782, 'user_location': 'US | CANADA | FRANCE | GERMANY', 'hashtags': "[{'text': 'Cannes', 'indices': [21, 28]}]", 'urls': 'N', 'media': 'N', 'text': 'RT @Variety: After a #Cannes rule change that bans films without a France theatrical release from playing in competition, @Netflix is sitti?'}
# {'_id': ObjectId('5ae3982378c51348e0df325f'), 'id': 984219494112428000, 'created_at': '4/11/2018 23:59', 'favourite_count': 0, 'retweet_count': 73, 'user_screen_name': 'paotrrzs', 'user_followers_count': 598, 'user_location': 'M\x82xico', 'hashtags': '[]', 'urls': 'N', 'media': 'N', 'text': 'RT @westmetromommy: Seriously, if you haven?t checked out @EverythingSuxTV on @netflix , you don?t know what you?re missing. It?s not too?'}
# {'_id': ObjectId('5ae3982378c51348e0df3260'), 'id': 984219485954630000, 'created_at': '4/11/2018 23:59', 'favourite_count': 0, 'retweet_count': 38, 'user_screen_name': 'Sense8giflord', 'user_followers_count': 484, 'user_location': 'Florida, USA', 'hashtags': '[]', 'urls': 'N', 'media': 'N', 'text': 'RT @Global_Cluster: I have somethings to say, @Netflix. You remember very well that we are very passionate fans. "A cult" . "Trolls". "Scar?'}
# {'_id': ObjectId('5ae3982378c51348e0df3261'), 'id': 984219472675434000, 'created_at': '4/11/2018 23:59', 'favourite_count': 0, 'retweet_count': 41, 'user_screen_name': 'angelicadianna_', 'user_followers_count': 267, 'user_location': None, 'hashtags': '[]', 'urls': 'N', 'media': 'N', 'text': 'RT @baleadalover: I don?t even watch this show but please @netflix @OnMyBlockTv recast her for new seasons. No white trump supporter should?'}
# {'_id': ObjectId('5ae3982378c51348e0df3262'), 'id': 984219470678974000, 'created_at': '4/11/2018 23:59', 'favourite_count': 5, 'retweet_count': 6, 'user_screen_name': 'paotrrzs', 'user_followers_count': 598, 'user_location': 'M\x82xico', 'hashtags': "[{'text': 'RenewEverythingSucks', 'indices': [41, 62]}]", 'urls': 'Y', 'media': 'N', 'text': '@netflix see how much we love it. Please #RenewEverythingSucks'}

# %%
#created at column has date and time information together.
#Since data is converted from csv to json,its format is string in the beginning.
#Thus datetime function of python is used to convert created_at into a right format.

def to_datetime(datestring):    
    dt = datetime.strptime(datestring.strip(), '%Y-%m-%d %H:%M:%S') 
    #dt = dt.utcnow()    
    return dt

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words_list = list(stopwords.words('english'))
stop_words={}
for tag in stop_words_list:
    stop_words[tag]=0
print (stop_words.keys())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kilic\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# dict_keys(['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"])

# %%
#This tokenize function extracts words by certain rules. For instance blanks or punctuation marks in the text are used to split words.
import re
def tokenize(txt):  
  txt=re.sub(r'\n', ' ',txt)
  txt=re.compile(r'[\.][ ]+').sub(' ',txt)      
  txt=re.compile(r'[\,][ ]+').sub(' ',txt)    
  txt=re.compile(r'[_+;=!@$%^&\*\"\?]').sub(' ',txt)  
  splitter=re.compile(r'[ ]+')
  # Split the words by non-alpha characters
  words=splitter.split(txt)
  return words
print (tokenize(d['text']))
# Out:
# ['', 'netflix', 'see', 'how', 'much', 'we', 'love', 'it', 'Please', '#RenewEverythingSucks']

# %%
def update_urls_tags(url_list,urls,hashtag_list,hashtags,tag_list,tags):  
  for url in url_list:
      if url in urls:
        urls[url]=urls[url]+1
      else:
        urls[url]=1	 
  for tag in tag_list:
      if tag in tags:
        tags[tag]=tags[tag]+1
      else:
        tags[tag]=1	 
  for hashtag in hashtag_list:
      if hashtag in hashtags:
        hashtags[hashtag]=hashtags[hashtag]+1
      else:
        hashtags[hashtag]=1        
  return urls,hashtags,tags

# %%
hashtags={}
starter_tags=['tvshow','tvseries']
for tag in starter_tags:
    hashtags[tag]=0
urls={}
tags={}
print(hashtags)
# Out:
# {'tvshow': 0, 'tvseries': 0}

# %%
def extract_tags_urls(dct,words,stop):
  i=0
  tags={} 
  tokens={}     
  urls={}     
  size=len(words)   
  while i < size:
    ngram = words[i]
    i=i+1
    if len(ngram) < 1: continue
    if len(ngram) > 4:        
      if ngram[0:4].lower()=='http':
        if ngram in urls:
          urls[ngram]=urls[ngram]+1
        else:
          urls[ngram]=1	 
    if ngram[0]=='#':
  #    ngram=re.sub(r'\#', '',ngram)     if you want to remove the # 
      tags[ngram]=1 
    if ngram.lower() not in stop:    
        tokens[ngram]=1	          
    if ngram in dct:
      tags[ngram]=1
    if i < (size-1):
      ngram = words[i] + ' ' + words[i+1]
      if words[i].lower() not in stop:    
        tokens[ngram]=1	        
      if ngram in dct:
        tags[ngram]=1
    if i < (size-2):
      ngram = words[i] + ' ' + words[i+1] + ' ' + words[i+2]           
      if ngram in dct:
        tags[ngram]=1
  return list(tags.keys()),list(urls.keys()),list(tokens.keys())
print (extract_tags_urls(hashtags,(tokenize(d['text'])),stop_words))
# Out:
# (['#RenewEverythingSucks'], [], ['netflix', 'see how', 'see', 'much we', 'much', 'love it', 'love', 'Please #RenewEverythingSucks', 'Please', '#RenewEverythingSucks'])

# %%
#Following code keeps records of used hashtags and how many times they are used.

cnt=0
for tweet in new:
   #
    retweet_count=0
    try:
        retweet_count=int(tweet['retweet_count'])
    except:        
        pass   
    tweet_tags,tweet_urls,tweet_ngrams=extract_tags_urls(hashtags,(tokenize(tweet['text'])),stop_words)
    print (tweet_tags)
    urls,hashtags,tags=update_urls_tags(tweet_urls,urls,tweet_tags,hashtags,tweet_ngrams,tags)
    try:
        
        #j=tweet_json(tweet['id'],tweet['text'],ts,favorite_count,retweet_count,tweet_urls,tweet_tags)
        j=new(tweet['Date'], tweet['Time'], tweet['id'],tweet['text'],tweet['user_screen_name'], tweet['user_location'], tweet['user_followers_count'],retweet_count,tweet_tags)
        result = collection.insert_one(j)
        cnt+=1
    except:
        pass       
print ("%d tweets inserted."%cnt)
# Out:
# ['#Cannes']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# ['#ToAllTheBoysIveLovedBefore']
# []
# []
# []
# []
# ['#reneweverythingsucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#iamkatemessner']
# []
# ['#RenewGypsy', '#GypsyMatters']
# ['#reneweverythingsucks', '#iamkatemessner']
# []
# ['#WhenYou']
# []
# ['#RenewGypsy', '#GypsyMatters']
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#Banff2018']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# []
# ['#RenewEverythingSu']
# []
# []
# []
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#Philippines', '#Duterte']
# []
# ['#reneweverythingsucks']
# []
# ['#StreamTeam', '#me', '#reviews']
# []
# []
# []
# ['#HBTL']
# []
# ['#HBTL']
# []
# []
# []
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks', '#SaveEverythingSucks']
# []
# []
# []
# ['#Yodeldale']
# []
# ['#reneweverythingsucks']
# []
# []
# []
# []
# ['#ThingsImAfraidOfLosing']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewOnMyBlock']
# []
# []
# ['#Movies', '#RoxanneRoxanne', '#MovieReview', '#Dope', '#HipHop', '#Blerd', '#Nerd', '#Geek']
# ['#reneweverythingsucks']
# []
# []
# []
# []
# ['#JayZ']
# ['#RenewOnMyBlock']
# ['#SaveFore']
# []
# ['#NetflixWeNeedSupernatural']
# ['#eusoupercystente']
# []
# []
# ['#fastestcar', '#TeamSalamone', '#winning']
# []
# []
# ['#SaveFor']
# []
# []
# []
# []
# []
# []
# ['#RandomForeverThought', '#SaveForever']
# ['#RenewEverythingSucks']
# []
# []
# ['#nosen']
# []
# []
# []
# []
# ['#Diablero']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#Onmyblock']
# ['#Travelers']
# ['#EverythingSucks', '#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks', '#Netflix']
# []
# ['#LostInSpace']
# ['#RenewEverthingSucks']
# []
# ['#Castlevania', '#CastlevaniaS2']
# []
# []
# []
# ['#narrativeart', '#ComicArt', '#comicbo']
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#Sense8']
# []
# []
# ['#RenewEverythingSucks', '#IAmKateMessner']
# ['#LostInSpace']
# ['#RenewEverythingSucks']
# ['#sense8', '#disjointed']
# []
# ['#reneweverythingsucks']
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#TheTerror', '#TheTitanMovie']
# ['#reneweverythingsucks']
# ['#Onmyblock', '#OnMyBlock']
# []
# []
# ['#RenewEverythingSucks']
# ['#Gypsy']
# ['#reneweverythingsucks']
# []
# []
# []
# ['#CasaDePapel']
# ['#RenewOnMyBlock']
# []
# []
# []
# ['#calusacon']
# []
# []
# []
# []
# []
# []
# []
# ['#RoyaltyFree', '#UHD']
# []
# []
# []
# []
# []
# []
# []
# ['#ASeriesOfUnfortunateEvents']
# ['#BoycottNetflix']
# ['#SheRa', '#PrincessesOfPowe']
# []
# ['#BoycottNetflix']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['#XenaRevival', '#X']
# ['#jadore', '#bonbonpourlesyeux']
# []
# []
# []
# ['#Netflix']
# []
# ['#RenewGypsy', '#GypsyMatters']
# []
# []
# []
# ['#tiff']
# ['#RenewEverythingSucks']
# []
# []
# ['#R']
# []
# []
# ['#reneweverythingsucks']
# []
# []
# []
# ['#Cannes']
# []
# []
# ['#Black']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# []
# ['#RenewOnMyBlock']
# []
# []
# []
# []
# []
# ['#Netflix', '#TV', '#Comedy', '#Animation', '#BigMouth', '#Cartoons', '#NSFW']
# ['#RenewEverythingSucks']
# []
# ['#renewonmyblock', '#ruby', '#onmyblock', '#insquadwetrust', '#kbye']
# []
# []
# ['#reneweverythingsucks']
# []
# []
# []
# []
# []
# ['#ASeriesOfUnfortunateEvents']
# []
# []
# []
# []
# ['#onmyblock']
# []
# ['#Legion']
# ['#reneweverythingsucks']
# ['#RenewEveryThingSucks']
# ['#onmyblock']
# []
# []
# []
# ['#WildWildCountry']
# []
# []
# []
# ['#RenewEverythingSucks', '#SaveEverythingSucks', '#iamkatemessner', '#iamemalineaddario']
# ['#RenewEverythingSucks']
# ['#Travelers']
# ['#RenewGypsy', '#GypsyMatters']
# ['#Netflix']
# []
# ['#CANNESERIES', '#Safe']
# []
# []
# ['#renewEverythingSucks']
# ['#reneweverythi']
# ['#reneweverythingsuck']
# []
# []
# ['#sense8']
# []
# ['#RenewEverythingSucks']
# ['#Episodes']
# []
# []
# []
# []
# ['#AnotherSeason', '#Netflix']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#iamka']
# ['#Netflix', '#RenewEverythin']
# []
# ['#firstteam']
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewGypsy', '#GypsyMatters']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#Rapture']
# ['#reneweverthingsucks']
# ['#reneweverythingsucks']
# []
# []
# ['#iamkatemessner', '#RenewEverythingSucks']
# []
# []
# []
# []
# []
# ['#IAmKateMessner', '#RenewEverythingSucks']
# []
# []
# []
# []
# ['#OneMoreSeason', '#Netflix']
# []
# ['#uglydelicious']
# []
# ['#renewEverythingSucks']
# ['#RenewEverythingSuck']
# []
# ['#everythingsucks', '#reneweverythingsucks']
# []
# ['#RenewEverthingSucks']
# ['#RenewEverythingSucks', '#iamka']
# ['#RenewEverythingSucks']
# ['#Rene']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# ['#EverythingSucks']
# ['#RenewOnMyBlock']
# ['#renewonmyblock']
# ['#BoycottNetflix']
# []
# []
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#iamkatemessner', '#']
# ['#Boone']
# ['#RenewEverthingSucks', '#WeDeserveASeason2', '#WeAreBoringHigh', '#iamemalineaddario', '#iamtylerbowen']
# []
# ['#Gypsy', '#RenewGypsy', '#GypsyMatters', '#Ma']
# ['#RenewEverythingSucks']
# []
# ['#Gpysy']
# ['#RenewEverythingSucks']
# ['#RenewGypsy', '#GypsyMatters', '#MarenHeary', '#Netflix', '#lgbt']
# ['#RenewEverythingSucks']
# ['#donatehfc']
# ['#RenewEverythingSucks']
# []
# ['#eusoupercystente']
# ['#sense8']
# ['#lostinspace', '#MarkGoddard']
# []
# ['#RenewGypsy', '#GypsyMatters', '#NaomiWatts', '#MarenHeary', '#Netf']
# ['#RenewGypsy', '#GypsyMatters', '#MarenHeary', '#Netflix', '#lgbt']
# []
# []
# []
# ['#GypsyNetflix']
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewGypsy', '#GypsyMatters', '#BringBackGypsy']
# ['#iamkatemessner', '#RenewEverythingSucks']
# []
# []
# ['#RenewGypsy']
# []
# []
# []
# ['#RenewGypsy']
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# ['#renewonmyblock']
# []
# ['#Gypsy', '#RenewGypsy', '#GypsyMatters']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#EverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# []
# ['#reneweverythingsucks', '#iamkatemessner']
# ['#Borders']
# ['#RenewEverythingSucks', '#iamkatemessner']
# ['#Ruta35', '#badboy']
# []
# []
# ['#Ruta35']
# ['#RenewEverythingSucks']
# ['#RenewGypsy', '#GypsyMatters']
# ['#reneweverythingsucks']
# ['#reneweverythingsucks', '#renewever']
# ['#reneweverythingsucks']
# ['#GypsyMatters', '#RenewGypsy']
# []
# ['#iamkatemessner', '#RenewEverythingSucks']
# []
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# []
# ['#reneweverythingsucks']
# ['#reneweverythingsucks']
# ['#reneweverythingsucks']
# []
# []
# []
# ['#RenewGypsy']
# []
# []
# ['#TechInfiltration']
# ['#RenewGypsy', '#GypsyMatters']
# []
# ['#RenewGypsy', '#GypsyMatters']
# ['#RenewGypsy', '#GypsyMatters', '#Gypsyseason2', '#Jeaney']
# []
# []
# []
# ['#RenewGypsy', '#GypsyMatters']
# ['#reneweverythingsucks']
# []
# ['#RenewEverythingSucks']
# ['#reneweverthingsucks']
# ['#RenewEveryThingSucks']
# ['#reneweverythingsucks']
# ['#RenewGypsy', '#GypsyMatters']
# ['#EverythingSucks']
# ['#Reneweverythingsucks']
# ['#Gypsy']
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#RenewEveryThingSucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['#RenewEverthingSucks']
# []
# []
# ['#RenewEverythingSucks', '#IAmKateMessner']
# ['#EverythingSucks']
# []
# []
# ['#OnMyBlock']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks', '#iamkatemessne']
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#GagaFiveFootTwo']
# ['#RenewEverythingSucks']
# ['#RenewGypsy', '#GypsyMatters']
# []
# ['#reneweverythingsucks']
# []
# ['#RenewEverythingSucks', '#SaveEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks', '#iamkatemessner']
# ['#Obama']
# ['#Reboot', '#GuardianCode']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#Alzheimers']
# ['#iamkatemessner', '#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#HumpDay', '#GaleHarold', '#BrianKinney', '#JustinTaylor', '#RandyHarrison']
# []
# []
# []
# []
# ['#Kemaline', '#reneweverythingsucks']
# []
# ['#MST3K', '#MST3KMotivation', '#TheDude', '#MST3KTheReturn']
# ['#RenewEverythingSucks']
# ['#RenewGypsy', '#GypsyMatters']
# ['#DrugWar', '#C']
# []
# ['#XenaRevival']
# []
# []
# []
# ['#Ja']
# []
# ['#13ReasonsWhy']
# ['#reneweverythingsucks']
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks', '#SaveEverythingSucks', '#iamkatemessner']
# []
# ['#lostinspace']
# ['#RENEWEVERYTHINGSUCKS']
# ['#RenewOnMyBlock', '#OnMyBlock']
# []
# []
# ['#RenewGypsy', '#GypsyMat']
# ['#RenewEverythingSucks']
# []
# []
# ['#LostInSpace', '#LOST']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#OnMyBlock']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks', '#saveverythingsucks']
# []
# ['#renewed']
# ['#savethelibrarians']
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#HilarityforCharity']
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['#Netflix', '#RenewEverythi']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# []
# ['#Netflix']
# []
# ['#RenewEverthingSucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#News', '#StrangerThings']
# []
# []
# ['#GiveSense8Season3']
# []
# []
# []
# []
# []
# ['#renewonmyblock']
# ['#FastestCar', '#fail']
# []
# ['#onmyblock']
# ['#RenewEverthingSucks']
# ['#AV1']
# ['#RenewEverythingSucks']
# []
# []
# ['#reneweverythingsucks']
# ['#BatB']
# ['#BatBMagic']
# ['#JessicaJones']
# ['#BatB', '#BatBMagic']
# []
# []
# []
# ['#BatB']
# ['#RenewEverythingSucks']
# ['#BatB', '#BatBMagic']
# []
# ['#EverythingSucks', '#RenewEverythingSucks']
# []
# []
# ['#BatB', '#BatBMagic']
# ['#RenewEverythingSuc']
# []
# ['#BatBMagic', '#BATB']
# ['#BatB', '#BatBMagic']
# []
# ['#BATB', '#BatBMagic']
# []
# ['#BatB', '#BatBMagic']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# ['#BatB', '#BatBMagic']
# []
# ['#BatB']
# ['#BatB', '#BatBMagic']
# ['#BatBMagic', '#BATB']
# ['#EverythingSucks']
# []
# []
# ['#reneweverythingsucks']
# ['#XenaR']
# []
# ['#reneweverythingsucks']
# ['#JessicaJones']
# []
# ['#RenewEverythingSucks', '#IamKateMessner', '#IamEmalineAddario']
# ['#RenewEveryThingSucks']
# ['#B']
# []
# ['#XenaRevival', '#OriginalCast']
# ['#TheDirt']
# ['#RenewEverythingSucks']
# ['#BatB', '#BatBMagi']
# []
# []
# []
# ['#XenaRevival', '#OriginalCast']
# []
# ['#XenaRevival', '#XenitesUnite', '#XXisforXENA']
# []
# ['#JessicaJones']
# ['#XenaMovie', '#XenaRevival']
# ['#BatB']
# ['#theCUBE', '#FlinkF']
# ['#XenaRevival', '#XXisforXENA', '#LucyLawless', '#ReneeOConnor']
# ['#JessicaJones']
# []
# []
# ['#reneweverythingsucks', '#iamkatemessner']
# []
# ['#XenaRevival', '#NoReboot']
# ['#RenewEverythingSucks']
# ['#QTNTBA']
# []
# []
# ['#DirkGently']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#JessicaJones']
# []
# []
# ['#RenewEverythingSucks', '#IamKateMessner', '#IamEmalineAddario']
# []
# ['#XenaRevival', '#XenitesUnite', '#XXisforXENA']
# ['#JessicaJones']
# []
# ['#AskJennifer']
# []
# ["#BrillanteMendoza's", '#Amo']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#XenaRevival', '#XXisforXENA']
# ['#reneweverythingsucks']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks', '#IamKateMessner', '#IamEmalineAddario']
# ['#Aggretsuko']
# ['#XenaRevival', '#Xena']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#Renew']
# []
# []
# ['#NeverForget']
# []
# []
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# []
# ['#BringbackBobsBurgers', '#BobsBurgers']
# []
# ['#RenewEverythingSucks']
# ['#XenaRevival']
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# ['#SCTV']
# []
# []
# []
# []
# ['#reneweverythingsucks', '#saveeverythingsucks', '#r']
# []
# ['#RenewEverythingSucks']
# []
# ['#XenaRevival', '#X']
# ['#reneweverythingsucks']
# []
# []
# []
# []
# []
# ['#reneweverythingsucks']
# ['#iamkatemessner', '#RenewEverythingSucks']
# []
# []
# ['#SNL']
# ['#RenewEverythingSucks']
# []
# ['#DirkGently', '#dirkgentlyisntover']
# []
# ['#everythingsucks', '#RenewEverythingSucks']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['#Yodeldale']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks', '#WeNeedseason2', '#SaveEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# ['#USA']
# []
# []
# []
# []
# ['#Ruta35']
# []
# []
# []
# ['#reneweverythingsucks', '#iamkatemessner', '#iamemali']
# ['#RenewEverythingSucks']
# []
# ['#JessicaJones']
# []
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# []
# []
# []
# []
# []
# []
# []
# []
# ['#RenewEverythingSucks', '#SaveEverythingSucks']
# ['#reneweverythingsucks']
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#Android']
# []
# []
# ['#RenewEverythi']
# ['#reneweverythingsucks', '#iamkatemessner', '#RepresentationMatters']
# []
# ['#care2', '#AmericasNextNewArtist']
# ['#JessicaJones']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#ESPECT']
# []
# ['#care2', '#AmericasNextNewArtist']
# []
# ['#reneweverythingsucks', '#iamkatemessner']
# []
# ['#Godless']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverthingSucks']
# ['#RenewEvery']
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks', '#iamemalineaddario', '#iamkatemessner', '#weareboringhigh', '#representationmatters']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#renewEverythingSucks']
# ['#reneweverythingsucks', '#netflix']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#uglydelicious']
# ['#RenewEverythingSucks']
# ['#renewonmyblock']
# ['#NailedIt']
# ['#Gypsy', '#Gypsy2']
# ['#RenewEverythingSucks']
# ['#Safe']
# []
# []
# ['#RenewEverthingSucks']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# []
# ['#PrettyLittleLiars']
# ['#RenewEvery']
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverthingSucks', '#IAmMcQuaid']
# ['#RenewEverythingsucks']
# []
# []
# []
# []
# []
# []
# ['#Troya']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#JessicaJones']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#XenaRevival', '#Xena']
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewOnMyBlock']
# []
# ['#reneweverythingsucks']
# []
# []
# []
# []
# []
# ['#RENEWEVERYTHINGSUCKS']
# ['#renewe']
# ['#RenewEverythingSucks']
# ['#EverythingSucks']
# []
# []
# []
# ['#reneweverythingsucks']
# []
# []
# []
# []
# ['#PrettyLittleLiars']
# ['#XenitesUnite', '#XXisforXENA']
# []
# ['#BehindTheCurtain']
# []
# []
# []
# ['#XenaRevival', '#Xena', '#X']
# ['#onmyblock']
# []
# []
# []
# []
# ['#XenitesUnite', '#XXisforXENA']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#WeAreBoringHigh', '#RenewEverthingSucks']
# []
# []
# []
# []
# []
# []
# ['#XenaRevival', '#XenaMovie']
# ['#Amo']
# ['#reneweverythingsucks']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#wildwildcountry']
# []
# ['#reneweverythingsucks']
# ['#GenitalEquality']
# ['#reneweverythingsucks']
# []
# []
# []
# []
# []
# ['#reneweverythingsucks']
# ['#reneweverythingsucks']
# ['#Mindhunter']
# []
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# ['#sense8']
# ['#reneweverythingsucks']
# []
# ['#reneweverythingsucks']
# ['#SaveEverythingSucks', '#RenewEveryThingSucks', '#IAmKateMessner']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# ['#RenewEverythingSucks', '#IamKateMessner', '#IamEmalineAddario']
# []
# ['#RenewEverythingsucks']
# ['#RenewEverythingsSucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#reneweveryhingsucks', '#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#everythingsucks']
# ['#RenewEverythingSucks']
# []
# ['#HarveyAndSabrina']
# []
# []
# ['#Thundercats', '#ThundercatsRemake', '#Dreamwor']
# []
# []
# []
# ['#IAmAGallagher', '#Shameless']
# []
# []
# []
# []
# []
# ['#Netflix']
# []
# ['#EverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# ['#reneweverthingsucks']
# []
# []
# ['#onmyblock']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverthingSucks', '#WeAreBoringHigh', '#IAmKateMessner']
# ['#21Thunder', '#singlegirl']
# []
# ['#HelloMyTwenties', '#Season3']
# ['#Netflix', '#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEveryThingSucks']
# []
# ['#RenewEverythingSucks']
# []
# ['#EverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEveryThingSucks', '#iamkatemessner', '#RepresentationMatters']
# ['#LostInSpace']
# ['#Obama', '#Netfilx', '#NetlixandChil']
# []
# ['#RenewEverythingSucks', '#RenewEverythingSuck']
# ['#RenewEverythingSucks', '#RenewEve']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks', '#iamkatemessner', '#kemaline', '#saveeverythingsucks']
# []
# []
# []
# []
# []
# ['#billboard', '#hollywood']
# []
# ['#RenewEverythingSucks']
# ['#renewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#izombie']
# ['#RenewEverythingSucks']
# []
# ['#RenewEveryThingSucks']
# ['#reneweverythingsucks']
# ['#care2', '#AmericasNextNewArtist']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#renewEverythingSucks']
# ['#reneweveryhingsucks', '#reneweverythingsucks']
# []
# []
# []
# []
# []
# ['#renewEverythingSucks']
# ['#reneweverythingsucks']
# ['#TheWeekOf']
# ['#XenitesUnite', '#XenaRevival', '#XXisforXENA']
# []
# ['#RenewEverythingSucks', '#netflix']
# []
# ['#iamkatemessner']
# []
# []
# []
# ['#reneweverythingsucks']
# []
# ['#renewEverythingSucks']
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#Diablero']
# ['#renewEverythingSucks']
# ['#EverythingSucks', '#Re']
# ['#BoycottNetflix']
# []
# ['#reneweverythingsucks']
# ['#Netflix', '#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#renewEverythingSucks']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#strangerthings', '#savewillbyers']
# ['#reneweverythingsucks', '#saveeverythingsucks', '#saveeverythingsu']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks', '#saveeverythingsucks', '#renewe']
# ['#reneweverythingsucks', '#saveeverythingsucks', '#renew']
# []
# ['#reneweverythingsucks', '#saveeverythingsucks', '#saveevery']
# ['#renewEverythingSucks']
# ['#reneweverythingsucks', '#saveeverythingsucks', '#reneweverythingsu']
# []
# ['#reneweverythingsucks']
# []
# []
# ['#TEDTalks']
# ['#reneweverythingsucks']
# ['#Mindhunter']
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingsSucks']
# ['#TBT', '#TheHighwaymen']
# []
# ['#reneweve']
# ['#renewEverythingSucks']
# []
# ['#reneweverythingsucks']
# []
# ['#everythingsucks']
# []
# ['#renewEverythingSucks']
# []
# []
# ['#reneweverythingsucks']
# []
# []
# ['#Voltron']
# []
# ['#renewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#Reneweverythingsucks']
# ['#chicago']
# []
# ['#WildWildCountry']
# []
# ['#ToAllTheBoysIveLovedBefore']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# []
# ['#JessicaJones']
# []
# []
# []
# []
# ['#reneweverythingsucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingsSucks']
# ['#TuHaiMeraSunday']
# []
# []
# ['#reneweverythingsucks']
# []
# []
# []
# ['#JessicaJones']
# []
# ['#reneweverythingsucks']
# []
# ['#Cannes']
# ['#TheBabysitter']
# []
# ['#MartinScorsese', '#SCTV']
# ['#RenewEverythingSucks']
# []
# []
# ['#Webby']
# ['#Webby']
# ['#iamkatemessner']
# []
# []
# []
# []
# ['#reneweverythingsucks']
# ['#LostInSpace']
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingsSucks']
# []
# []
# []
# ['#Rene']
# []
# ['#OnMyBlock', '#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEve']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks', '#RenewEverythingsSucks']
# ['#LostInSpace']
# []
# []
# []
# ['#DarkMatter']
# ['#Reneweverythingsucks']
# ['#HHN28']
# ['#reneweverythingsucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks', '#']
# ['#reneweverythingsucks']
# []
# []
# ['#LostInSpace']
# []
# []
# []
# []
# []
# []
# ['#Longmire']
# []
# []
# []
# ['#Reneweverythingsucks']
# ['#LostInSpace2018']
# ['#RenewEverythingsSucks']
# ['#LostInSpace']
# []
# []
# ['#DeleteNetflix']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#iamkatemessner']
# []
# ['#RenewEverythingSucks', '#SaveEverythingSucks']
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#CasaDePapel']
# ['#RenewEverythingSucks']
# ['#EverythingSucks']
# []
# []
# []
# ['#wewantanswers', '#wewantpromotion']
# []
# ['#OnMyBlock']
# []
# ['#reneweverythingsucks']
# ['#ComeSunday']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# ['#insquadwetrust', '#SEASON2', '#OnMyBlock']
# []
# ['#reneweverythingsucks']
# []
# ['#reneweverythingsucks', '#RenewEverythingsSucks']
# ['#RenewEverythingsSucks']
# ['#FridayNight', '#FatherandSon']
# []
# []
# []
# []
# []
# ['#reneweverythingsucks']
# []
# ['#onmyblock']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#Friday..', '#Fridaythe13th..', '#AGG']
# ['#reneweverythingsucks']
# ['#RIPNetflix']
# []
# ['#LostInSpace']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSuc']
# ['#RenewEverythingSucks']
# ['#HHN28']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#goodfridaynight']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks', '#SaveEverythingSucks']
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#SAVEDIRKGENTLY', '#DIRKGENTLY']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#reneweverythingsucks']
# []
# ['#LostInSpace']
# []
# ['#1']
# []
# ['#pleeeze']
# []
# ['#reneweverythingsucks', '#1996']
# ['#LostInSpace', '#netflix', '#ne']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# ['#CESDTalent']
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# ['#RenewEverythingSuc']
# ['#cantpaywelltakeitaway']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#reneweverythingsucks']
# ['#']
# []
# []
# ['#Reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverythingSucks']
# ['#LostInSpace2018', '#LostInSpace']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#LostInSpace']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#OMBFam', '#OnMyBlock']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSu']
# []
# ['#']
# ['#']
# ['#Annihilation']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverything']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#reneweverythin']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#LostInSpace']
# []
# ['#renewEverythingSucks']
# []
# ['#reneweverythingsucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#puns', '#reneweverythingsucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# ['#reneweverythingsucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#DoctorFoster']
# []
# []
# ['#ChefsTablePastry']
# ['#RenewEverythingSucks']
# ['#WorldAutismMonth', '#WorldAutismAwarenessDay']
# ['#R']
# ['#RenewEverythingSucks']
# ['#Yodeldale']
# ['#reneweverythingsucks']
# ['#reneweverythingsucks']
# []
# []
# []
# ['#']
# ['#renewEverythingSuc']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# []
# ['#RenewEvery']
# ['#RenewEverythingSucks']
# []
# ['#WeWantEyewitnessSeason2']
# []
# ['#PorqueQuiereS3xo']
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# ['#ChefsTablePastry']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#BLACKPOWERWHITEPOWDER', '#RAPture']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# []
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#WeWantEyewitnessSeason2', '#PhilkasF']
# ['#RenewEverythingSucks']
# []
# ['#RenewEver']
# ['#ComeSunday']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# []
# ['#RenewEverything']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks', '#iamkatemessner']
# []
# ['#RenewEverythingSucks']
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewEver']
# []
# ['#reneweverythingsucks', '#saveeverythingsucks']
# []
# ['#reneweverythingsucks']
# []
# ['#RenewEverythingSucks']
# ['#1']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#reneweverythingsucks']
# []
# ['#reneweverythingsucks', '#RenewEverythingsSucks']
# []
# []
# []
# ['#StarTrek', '#Enterprise']
# []
# []
# ['#RenewEverythingSucks']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# []
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#IrreplaceableYou']
# []
# []
# ['#RenewEverythingSucks']
# ['#LostInSpace']
# []
# ['#TuHaiMeraSunday']
# []
# ['#OnMyBlock']
# ['#RenewEverythingSucks']
# []
# []
# ['#LostInSpace']
# ['#OnMyBlock']
# ['#RenewEverythingsSucks']
# []
# ['#RenewEverythingS']
# []
# ['#reneweverythingsucks']
# []
# []
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks', '#RENEWES']
# []
# ['#RenewEverythingSucks']
# []
# ['#re']
# []
# []
# []
# []
# []
# ['#RenewEverythingSucks']
# ['#DangerWillRobinson']
# ['#RenewEverythingSucks']
# ['#reneweverythingsucks']
# ['#reneweverythingsucks']
# ['#RenewEverythingSucks']
# ['#RenewEverythingSucks']
# 0 tweets inserted.

# %% [markdown]
# ### i. What are people saying about netflix?

# %% [markdown]
# This function keep track of hashtag itself and the number of times it is used by (key, value) structure. Key refers to hashtag and value is the number which is updated in hashtag search process.

# %%
for key, value in hashtags.items():
    print ("%s count %d"%(key, value))
# Out:
# tvshow count 0
# tvseries count 0
# #Cannes count 3
# #RenewEverythingSucks count 302
# #ToAllTheBoysIveLovedBefore count 2
# #reneweverythingsucks count 148
# #iamkatemessner count 24
# #RenewGypsy count 24
# #GypsyMatters count 20
# #WhenYou count 1
# #Banff2018 count 1
# #RenewEverythingSu count 2
# #Philippines count 1
# #Duterte count 1
# #StreamTeam count 1
# #me count 1
# #reviews count 1
# #HBTL count 2
# #SaveEverythingSucks count 9
# #Yodeldale count 3
# #ThingsImAfraidOfLosing count 1
# #RenewOnMyBlock count 7
# #Movies count 1
# #RoxanneRoxanne count 1
# #MovieReview count 1
# #Dope count 1
# #HipHop count 1
# #Blerd count 1
# #Nerd count 1
# #Geek count 1
# #JayZ count 1
# #SaveFore count 1
# #NetflixWeNeedSupernatural count 1
# #eusoupercystente count 2
# #fastestcar count 1
# #TeamSalamone count 1
# #winning count 1
# #SaveFor count 1
# #RandomForeverThought count 1
# #SaveForever count 1
# #nosen count 1
# #Diablero count 2
# #Onmyblock count 2
# #Travelers count 2
# #EverythingSucks count 12
# #Netflix count 14
# #LostInSpace count 16
# #RenewEverthingSucks count 11
# #Castlevania count 1
# #CastlevaniaS2 count 1
# #narrativeart count 1
# #ComicArt count 1
# #comicbo count 1
# #Sense8 count 1
# #IAmKateMessner count 5
# #sense8 count 4
# #disjointed count 1
# #TheTerror count 1
# #TheTitanMovie count 1
# #OnMyBlock count 10
# #Gypsy count 5
# #CasaDePapel count 2
# #calusacon count 1
# #RoyaltyFree count 1
# #UHD count 1
# #ASeriesOfUnfortunateEvents count 2
# #BoycottNetflix count 4
# #SheRa count 1
# #PrincessesOfPowe count 1
# #XenaRevival count 17
# #X count 3
# #jadore count 1
# #bonbonpourlesyeux count 1
# #tiff count 1
# #R count 2
# #Black count 1
# #TV count 1
# #Comedy count 1
# #Animation count 1
# #BigMouth count 1
# #Cartoons count 1
# #NSFW count 1
# #renewonmyblock count 5
# #ruby count 1
# #onmyblock count 7
# #insquadwetrust count 2
# #kbye count 1
# #Legion count 1
# #RenewEveryThingSucks count 8
# #WildWildCountry count 2
# #iamemalineaddario count 3
# #CANNESERIES count 1
# #Safe count 2
# #renewEverythingSucks count 14
# #reneweverythi count 1
# #reneweverythingsuck count 1
# #Episodes count 1
# #AnotherSeason count 1
# #iamka count 2
# #RenewEverythin count 1
# #firstteam count 1
# #Rapture count 1
# #reneweverthingsucks count 3
# #OneMoreSeason count 1
# #uglydelicious count 2
# #RenewEverythingSuck count 2
# #everythingsucks count 4
# #Rene count 2
# # count 6
# #Boone count 1
# #WeDeserveASeason2 count 1
# #WeAreBoringHigh count 3
# #iamtylerbowen count 1
# #Ma count 1
# #Gpysy count 1
# #MarenHeary count 3
# #lgbt count 2
# #donatehfc count 1
# #lostinspace count 2
# #MarkGoddard count 1
# #NaomiWatts count 1
# #Netf count 1
# #GypsyNetflix count 1
# #BringBackGypsy count 1
# #Borders count 1
# #Ruta35 count 3
# #badboy count 1
# #renewever count 1
# #TechInfiltration count 1
# #Gypsyseason2 count 1
# #Jeaney count 1
# #Reneweverythingsucks count 5
# #iamkatemessne count 1
# #GagaFiveFootTwo count 1
# #Obama count 2
# #Reboot count 1
# #GuardianCode count 1
# #Alzheimers count 1
# #HumpDay count 1
# #GaleHarold count 1
# #BrianKinney count 1
# #JustinTaylor count 1
# #RandyHarrison count 1
# #Kemaline count 1
# #MST3K count 1
# #MST3KMotivation count 1
# #TheDude count 1
# #MST3KTheReturn count 1
# #DrugWar count 1
# #C count 1
# #Ja count 1
# #13ReasonsWhy count 1
# #RENEWEVERYTHINGSUCKS count 2
# #GypsyMat count 1
# #LOST count 1
# #saveverythingsucks count 1
# #renewed count 1
# #savethelibrarians count 1
# #HilarityforCharity count 1
# #RenewEverythi count 2
# #News count 1
# #StrangerThings count 1
# #GiveSense8Season3 count 1
# #FastestCar count 1
# #fail count 1
# #AV1 count 1
# #BatB count 12
# #BatBMagic count 11
# #JessicaJones count 11
# #RenewEverythingSuc count 3
# #BATB count 3
# #XenaR count 1
# #IamKateMessner count 4
# #IamEmalineAddario count 4
# #B count 1
# #OriginalCast count 2
# #TheDirt count 1
# #BatBMagi count 1
# #XenitesUnite count 5
# #XXisforXENA count 7
# #XenaMovie count 2
# #theCUBE count 1
# #FlinkF count 1
# #LucyLawless count 1
# #ReneeOConnor count 1
# #NoReboot count 1
# #QTNTBA count 1
# #DirkGently count 2
# #AskJennifer count 1
# #BrillanteMendoza's count 1
# #Amo count 2
# #Aggretsuko count 1
# #Xena count 3
# #Renew count 1
# #NeverForget count 1
# #BringbackBobsBurgers count 1
# #BobsBurgers count 1
# #SCTV count 2
# #saveeverythingsucks count 8
# #r count 1
# #SNL count 1
# #dirkgentlyisntover count 1
# #WeNeedseason2 count 1
# #USA count 1
# #iamemali count 1
# #Android count 1
# #RepresentationMatters count 2
# #care2 count 3
# #AmericasNextNewArtist count 3
# #ESPECT count 1
# #Godless count 1
# #RenewEvery count 3
# #weareboringhigh count 1
# #representationmatters count 1
# #netflix count 3
# #NailedIt count 1
# #Gypsy2 count 1
# #PrettyLittleLiars count 2
# #IAmMcQuaid count 1
# #RenewEverythingsucks count 2
# #Troya count 1
# #renewe count 2
# #BehindTheCurtain count 1
# #wildwildcountry count 1
# #GenitalEquality count 1
# #Mindhunter count 2
# #RenewEverythingsSucks count 10
# #reneweveryhingsucks count 2
# #HarveyAndSabrina count 1
# #Thundercats count 1
# #ThundercatsRemake count 1
# #Dreamwor count 1
# #IAmAGallagher count 1
# #Shameless count 1
# #21Thunder count 1
# #singlegirl count 1
# #HelloMyTwenties count 1
# #Season3 count 1
# #Netfilx count 1
# #NetlixandChil count 1
# #RenewEve count 2
# #kemaline count 1
# #billboard count 1
# #hollywood count 1
# #izombie count 1
# #TheWeekOf count 1
# #Re count 1
# #strangerthings count 1
# #savewillbyers count 1
# #saveeverythingsu count 1
# #renew count 1
# #saveevery count 1
# #reneweverythingsu count 1
# #TEDTalks count 1
# #TBT count 1
# #TheHighwaymen count 1
# #reneweve count 1
# #Voltron count 1
# #chicago count 1
# #TuHaiMeraSunday count 2
# #TheBabysitter count 1
# #MartinScorsese count 1
# #Webby count 2
# #DarkMatter count 1
# #HHN28 count 2
# #Longmire count 1
# #LostInSpace2018 count 2
# #DeleteNetflix count 1
# #wewantanswers count 1
# #wewantpromotion count 1
# #ComeSunday count 2
# #SEASON2 count 1
# #FridayNight count 1
# #FatherandSon count 1
# #Friday.. count 1
# #Fridaythe13th.. count 1
# #AGG count 1
# #RIPNetflix count 1
# #goodfridaynight count 1
# #SAVEDIRKGENTLY count 1
# #DIRKGENTLY count 1
# #1 count 2
# #pleeeze count 1
# #1996 count 1
# #ne count 1
# #CESDTalent count 1
# #cantpaywelltakeitaway count 1
# #OMBFam count 1
# #Annihilation count 1
# #RenewEverything count 2
# #reneweverythin count 1
# #puns count 1
# #DoctorFoster count 1
# #ChefsTablePastry count 2
# #WorldAutismMonth count 1
# #WorldAutismAwarenessDay count 1
# #renewEverythingSuc count 1
# #WeWantEyewitnessSeason2 count 2
# #PorqueQuiereS3xo count 1
# #BLACKPOWERWHITEPOWDER count 1
# #RAPture count 1
# #PhilkasF count 1
# #RenewEver count 2
# #StarTrek count 1
# #Enterprise count 1
# #IrreplaceableYou count 1
# #RenewEverythingS count 1
# #RENEWES count 1
# #re count 1
# #DangerWillRobinson count 1

# %% [markdown]
# In order to answer this question, scope is limited with used hashtags. If people is talking about something, it is assumed that he uses related hashtags.
#
# For the last 1 month, most of the tweets mentioning @netflix is related with tv show named "EverythingSucks". RenewEverythingSucks, reneweverythingsucks and SaveEverythingSucks hashtags are used more than 459 times in total indicating that people want this show to continue.
#
# LostinSpace(16) and JessicaJos(11) are the other popular tv shows. RenewGypsy is counted 24 times and considering another tag related with Gypsy - GypsyMatters(20), people also have talked about Gypsy and want tv series to continue.
#
# Comedy, Cartoons, News are the hashtags indicating genre while fail, me, FridayNight, goodfridaynight are defining mood of the user. Although, genre, mood, actor name etc. are used as hashtags, we can definitely say that people frequently talk about tv shows directly as it is expected.

# %% [markdown]
# ### ii. How viral are my posts?

# %% [markdown]
# Virality of a post can be measured in terms of total of retweets it gets. Since, retweets are the primary way to spread tweets.
#
# So, I defined Virality V = Total Retweets
#
# This formula can be used to find either virality of a single post or virality of all posts of user in a certain time period.
#
# In this case, Virality of users named "Libbybyerley1" and "SanversArgent" is found and their posts's virality is compared. Following code returns id of their tweets and number of rt's they get respectively.
#
# In total Libbybyerley1's 3 tweets have 43 retweets in total. Thus, V =43 (Virality of posts' between 4/11/2018 - 4/13/2018)
#
# In total SanversArgent's 3 tweet have 35 retweets. V= 35 (Virality of posts between 4/11/2018 - 4/13/2018)
#
# As a result, Libbybyerley1's total virality is greater than SanversArgent's total virality. However; in terms of average measurement, SanversArgent has more virality.

# %%
results1 = collection.find({'user_screen_name': "Libbybyerley1"},{"retweet_count":1,"id":1})
for d in results1:
    print(d)
# Out:
# {'_id': ObjectId('5ae3982378c51348e0df3278'), 'id': 984219153908290000, 'retweet_count': 13}
# {'_id': ObjectId('5ae3982378c51348e0df327d'), 'id': 984219115387834000, 'retweet_count': 13}
# {'_id': ObjectId('5ae3982378c51348e0df3331'), 'id': 984215972742615000, 'retweet_count': 17}

# %%
results2 = collection.find({'user_screen_name': "SanversArgent"},{"retweet_count":1,"id":1})
for d in results2:
    print(d)
# Out:
# {'_id': ObjectId('5ae3982378c51348e0df329f'), 'id': 984218521046577000, 'retweet_count': 35}

# %% [markdown]
# ### iii.  How much influence to my posts have?

# %% [markdown]
# Influence of a post can be measured in terms of total number of likes and retweets he gets with his tweets. Since, retweets and likes demonstrate how much a post gets people's attention. People's likes and retweets are seen in timeline of tweeter resulting in more people to notice the tweet. Therefore, retweets and likes are chosen as indicators of influence.
#
# So simply, Influence I = SUM(likes) + SUM(retweets)
# This formula can be used to find either influence of a single post or influence of all posts of user in a certain time period.
#
# In this case, influence of users named "paotrrzs" and "PolandCluster" is found and their posts's influence is compared. Following code returns id of their tweets and mumber of likes and fav they get respectively.
#
# In total paotrrzs's tweets have 26 likes and 172 retweets. I= 26 + 172 =178 (Influence of posts' between 4/11/2018 - 4/13/2018)
#
# In total PolandCluster's tweets have 3 likes and 93 retweets. I= 3 + 93 = 96 (Influence of posts' between 4/11/2018 - 4/13/2018)
#
# As a result, paotrrzs's posts have more influence than PolandCluster's posts.

# %%
results3 = collection.find({'user_screen_name': "paotrrzs"},{"retweet_count":1, "favourite_count":1,"id":1})
for d in results1:
    print(d)

# %%
results4 = collection.find({'user_screen_name': "PolandCluster"},{"retweet_count":1, "favourite_count":1,"id":1})
for d in results2:
    print(d)

# %% [markdown]
# ### xi. Should I add and picture or url to my post?

# %% [markdown]
# If tweet includes any media or url this information is stored in tweets and is extracted when tweets are collected by API. If tweet does not include media or url fiels of those attributes are seen as blank. WHen I stored collected data in csv, I replace those information with 'Y' and 'N'.
#
# Y in urls or media field refers to tweet including URL/Media.
# N in urls or media field refers to tweet without any URL or Media.
#
# Csv file which has 'Y' or 'N' in media/urls field is used to create NoSQL database.
#
# In order to answer this question, number of retweets and likes are considered, If tweet having media or url gets many likes or retweets, I should add them to my post to increase my tweets interaction. Average number of likes and Averafe number of retweets of tweets with URL/Media are compared with tweets without them.

# %%
results5= collection.aggregate([{'$group': {'_id':"$media", 'avgFav': {'$avg':"$favourite_count"} } }])
for d in results5:
    print(d)
# Out:
# {'_id': 'Y', 'avgFav': 3.3244444444444445}
# {'_id': 'N', 'avgFav': 1.7456375838926175}

# %%
results6= collection.aggregate([{'$group': {'_id':"$media", 'avgRT': {'$avg':"$retweet_count"} } }])
for d in results6:
    print(d)
# Out:
# {'_id': 'Y', 'avgRT': 1030.4666666666667}
# {'_id': 'N', 'avgRT': 68.99194630872483}

# %% [markdown]
# Results indicate that tweets with media get more retweets and likes compared with tweets without media. Especially, avgRT that tweets with media get is 15 times higher than tweets without media get.

# %%
results7= collection.aggregate([{'$group': {'_id':"$urls", 'avgFav': {'$avg':"$favourite_count"} } }])
for d in results7:
    print(d)
# Out:
# {'_id': 'Y', 'avgFav': 5.307888040712468}
# {'_id': 'N', 'avgFav': 0.9553706505295008}

# %%
results8= collection.aggregate([{'$group': {'_id':"$urls", 'avgRT': {'$avg':"$retweet_count"} } }])
for d in results8:
    print(d)
# Out:
# {'_id': 'Y', 'avgRT': 115.82442748091603}
# {'_id': 'N', 'avgRT': 218.70953101361573}

# %% [markdown]
# Results for tweets including urls is slighlty differerent than what we observed in media case. Although, similar results are observed for average likes (avgFav is greater for tweets having urls), average number of retweets is higher for tweets without urls.
#
# Therefore, I should definitely add media to increase my interaction, likes, rt's. Using urls also increases my likes, so I can also add them to my post.
